# %%
import pandas as pd
import numpy as np
import glob
from matplotlib import pyplot as plt

# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,3)

# %%
path = r'tmp_data/attack_ts/' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, parse_dates=[0], index_col=[0])
    li.append(df)

df = pd.concat(li, axis=0)

#df = pd.read_csv("tmp_data/attack_ts/attack_ts_august_week2.csv", parse_dates=[0], index_col=[0])

# %%
df
# Out:
#                     counter(mins) Dos scan44 scan11 nerisbotnet blacklist  \
# 2016-08-01 00:00:00          6382   0      0      0           0         1
# 2016-08-01 00:01:00          6383   0      0      0           0         1
# 2016-08-01 00:02:00          6384   0      0      0           0         1
# 2016-08-01 00:03:00          6385   0      0      0           0         1
# 2016-08-01 00:04:00          6386   0      0      0           0         1
# ...                           ...  ..    ...    ...         ...       ...
# 2016-07-31 23:55:00          6377   0      0      0           0         1
# 2016-07-31 23:56:00          6378   0      0      0           0         1
# 2016-07-31 23:57:00          6379   0      0      0           0         1
# 2016-07-31 23:58:00          6380   0      0      0           0         1
# 2016-07-31 23:59:00          6381   0      0      0           0         1
#
#                     anomaly-udpscan anomaly-sshscan anomaly-spam
# 2016-08-01 00:00:00               0               0            0
# 2016-08-01 00:01:00               0               0            0
# 2016-08-01 00:02:00               0               0            0
# 2016-08-01 00:03:00               0               0            0
# 2016-08-01 00:04:00               0               0            0
# ...                             ...             ...          ...
# 2016-07-31 23:55:00               0               0            0
# 2016-07-31 23:56:00               0               0            0
# 2016-07-31 23:57:00               0               0            0
# 2016-07-31 23:58:00               0               0            0
# 2016-07-31 23:59:00               0               0            0
#
# [37190 rows x 9 columns]

# %%
df.drop('counter(mins)', 1, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_13852/2533708550.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop('counter(mins)', 1, inplace=True)

# %%
df
# Out:
#                     Dos scan44 scan11 nerisbotnet blacklist anomaly-udpscan  \
# 2016-08-01 00:00:00   0      0      0           0         1               0
# 2016-08-01 00:01:00   0      0      0           0         1               0
# 2016-08-01 00:02:00   0      0      0           0         1               0
# 2016-08-01 00:03:00   0      0      0           0         1               0
# 2016-08-01 00:04:00   0      0      0           0         1               0
# ...                  ..    ...    ...         ...       ...             ...
# 2016-07-31 23:55:00   0      0      0           0         1               0
# 2016-07-31 23:56:00   0      0      0           0         1               0
# 2016-07-31 23:57:00   0      0      0           0         1               0
# 2016-07-31 23:58:00   0      0      0           0         1               0
# 2016-07-31 23:59:00   0      0      0           0         1               0
#
#                     anomaly-sshscan anomaly-spam
# 2016-08-01 00:00:00               0            0
# 2016-08-01 00:01:00               0            0
# 2016-08-01 00:02:00               0            0
# 2016-08-01 00:03:00               0            0
# 2016-08-01 00:04:00               0            0
# ...                             ...          ...
# 2016-07-31 23:55:00               0            0
# 2016-07-31 23:56:00               0            0
# 2016-07-31 23:57:00               0            0
# 2016-07-31 23:58:00               0            0
# 2016-07-31 23:59:00               0            0
#
# [37190 rows x 8 columns]

# %%
df_ph = df.resample('H').sum()

# %%
for col in df.columns:
    df_ph[col].plot(title=col)
    plt.show()
