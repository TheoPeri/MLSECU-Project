# %%
import pandas as pd
import numpy as np
import glob
from matplotlib import pyplot as plt

# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,3)

# %%
path = r'data/attack_ts/' # use your path
all_files = glob.glob(path + "/*.csv")

print(all_files)

li = []

for filename in all_files:
    df = pd.read_csv(filename, parse_dates=[0], index_col=[0])
    li.append(df)

df = pd.concat(li, axis=0)

#df = pd.read_csv("data/attack_ts/attack_ts_august_week2.csv", parse_dates=[0], index_col=[0])
# Out:
# ['data/attack_ts\\attack_ts_april_week2.csv', 'data/attack_ts\\attack_ts_april_week3.csv', 'data/attack_ts\\attack_ts_april_week4.csv', 'data/attack_ts\\attack_ts_april_week5.csv', 'data/attack_ts\\attack_ts_august_week1.csv', 'data/attack_ts\\attack_ts_august_week2.csv', 'data/attack_ts\\attack_ts_august_week3.csv', 'data/attack_ts\\attack_ts_august_week4.csv', 'data/attack_ts\\attack_ts_august_week5.csv', 'data/attack_ts\\attack_ts_july_week5.csv', 'data/attack_ts\\attack_ts_june_week1.csv', 'data/attack_ts\\attack_ts_june_week2.csv', 'data/attack_ts\\attack_ts_june_week3.csv', 'data/attack_ts\\attack_ts_june_week4.csv', 'data/attack_ts\\attack_ts_may_week1.csv', 'data/attack_ts\\attack_ts_may_week2.csv', 'data/attack_ts\\attack_ts_may_week3.csv', 'data/attack_ts\\attack_ts_may_week4.csv', 'data/attack_ts\\attack_ts_may_week5.csv', 'data/attack_ts\\attack_ts_may_week6.csv']

# %%
df
# Out:
#                     counter(mins) Dos scan44 scan11 nerisbotnet blacklist  \
# 2016-04-06 00:00:00         26713   0      0      0           0         0
# 2016-04-06 00:01:00         26714   0      0      0           0         0
# 2016-04-06 00:02:00         26715   0      0      0           0         0
# 2016-04-06 00:03:00         26716   0      0      0           0         0
# 2016-04-06 00:04:00         26717   0      0      0           0         0
# ...                           ...  ..    ...    ...         ...       ...
# 2016-05-31 23:55:00        107348   0      0      0           0         1
# 2016-05-31 23:56:00        107349   0      0      0           0         1
# 2016-05-31 23:57:00        107350   0      0      0           0         1
# 2016-05-31 23:58:00        107351   0      0      0           0         1
# 2016-05-31 23:59:00        107352   0      0      0           0         1
#
#                     anomaly-udpscan anomaly-sshscan anomaly-spam
# ...

# %%
df.drop('counter(mins)', 1, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_13440/2533708550.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop('counter(mins)', 1, inplace=True)

# %%
df
# Out:
#                     Dos scan44 scan11 nerisbotnet blacklist anomaly-udpscan  \
# 2016-04-06 00:00:00   0      0      0           0         0               0
# 2016-04-06 00:01:00   0      0      0           0         0               0
# 2016-04-06 00:02:00   0      0      0           0         0               0
# 2016-04-06 00:03:00   0      0      0           0         0               0
# 2016-04-06 00:04:00   0      0      0           0         0               0
# ...                  ..    ...    ...         ...       ...             ...
# 2016-05-31 23:55:00   0      0      0           0         1               0
# 2016-05-31 23:56:00   0      0      0           0         1               0
# 2016-05-31 23:57:00   0      0      0           0         1               0
# 2016-05-31 23:58:00   0      0      0           0         1               0
# 2016-05-31 23:59:00   0      0      0           0         1               0
#
#                     anomaly-sshscan anomaly-spam
# ...

# %%
df_ph = df.resample('H').sum()

# %%
for col in df.columns:
    df_ph[col].plot(title=col)
    plt.show()
